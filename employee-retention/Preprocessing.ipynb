# %%
import pandas as pd
import numpy as np 
data = pd.read_csv("C:/Users/irtiz/Desktop/FDS/FDS_DATA.csv")

# %%
data
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     51.0        No      Travel_Rarely                   Sales
# 1     31.0       Yes  Travel_Frequently  Research & Development
# 2     32.0        No  Travel_Frequently  Research & Development
# 3     38.0        No         Non-Travel  Research & Development
# 4     32.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 4406  29.0        No      Travel_Rarely  Research & Development
# 4407  25.0        No      Travel_Rarely  Research & Development
# 4408  42.0        No      Travel_Rarely                   Sales
# 4409  40.0        No      Travel_Rarely  Research & Development
# 4410   NaN       NaN                NaN                     NaN
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                  6.0        2.0  Life Sciences         1.0  Female
# ...

# %%
data.head(10)
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  51.0        No      Travel_Rarely                   Sales
# 1  31.0       Yes  Travel_Frequently  Research & Development
# 2  32.0        No  Travel_Frequently  Research & Development
# 3  38.0        No         Non-Travel  Research & Development
# 4  32.0        No      Travel_Rarely  Research & Development
# 5  46.0        No      Travel_Rarely  Research & Development
# 6  28.0       Yes      Travel_Rarely  Research & Development
# 7  29.0        No      Travel_Rarely  Research & Development
# 8  31.0        No      Travel_Rarely  Research & Development
# 9  25.0        No         Non-Travel  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeID  Gender  JobLevel  \
# 0               6.0        2.0  Life Sciences         1.0  Female       1.0
# 1              10.0        1.0  Life Sciences         2.0  Female       1.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4411 entries, 0 to 4410
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   float64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   float64
#  5   Education                4410 non-null   float64
#  6   EducationField           4410 non-null   object
#  7   EmployeeID               4410 non-null   float64
#  8   Gender                   4410 non-null   object
#  9   JobLevel                 4410 non-null   float64
#  10  JobRole                  4410 non-null   object
#  11  MaritalStatus            4410 non-null   object
#  12  MonthlyIncome            4410 non-null   float64
#  13  NumCompaniesWorked       4392 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeID', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance', 'JobInvolvement', 'PerformanceRating',
#        'Avg Time Spent(Mins)', 'Absences'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age                         1
# Attrition                   1
# BusinessTravel              1
# Department                  1
# DistanceFromHome            1
# Education                   1
# EducationField              1
# EmployeeID                  1
# Gender                      1
# JobLevel                    1
# JobRole                     1
# MaritalStatus               1
# MonthlyIncome               1
# NumCompaniesWorked         19
# PercentSalaryHike           1
# StockOptionLevel            1
# TotalWorkingYears          10
# TrainingTimesLastYear       1
# YearsAtCompany              1
# YearsSinceLastPromotion     1
# YearsWithCurrManager        1
# EnvironmentSatisfaction    26
# JobSatisfaction            21
# WorkLifeBalance            39
# JobInvolvement              1
# PerformanceRating           1
# Avg Time Spent(Mins)        1
# Absences                    1
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     51.0        No      Travel_Rarely                   Sales
# 1     31.0       Yes  Travel_Frequently  Research & Development
# 2     32.0        No  Travel_Frequently  Research & Development
# 3     38.0        No         Non-Travel  Research & Development
# 4     32.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 4404  29.0        No      Travel_Rarely                   Sales
# 4405  42.0        No      Travel_Rarely  Research & Development
# 4406  29.0        No      Travel_Rarely  Research & Development
# 4407  25.0        No      Travel_Rarely  Research & Development
# 4408  42.0        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                  6.0        2.0  Life Sciences         1.0  Female
# ...

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head(10)
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  51.0        No      Travel_Rarely                   Sales
# 1  31.0       Yes  Travel_Frequently  Research & Development
# 2  32.0        No  Travel_Frequently  Research & Development
# 3  38.0        No         Non-Travel  Research & Development
# 4  32.0        No      Travel_Rarely  Research & Development
# 5  46.0        No      Travel_Rarely  Research & Development
# 6  28.0       Yes      Travel_Rarely  Research & Development
# 7  29.0        No      Travel_Rarely  Research & Development
# 8  31.0        No      Travel_Rarely  Research & Development
# 9  25.0        No         Non-Travel  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeID  Gender  JobLevel  \
# 0               6.0        2.0  Life Sciences         1.0  Female       1.0
# 1              10.0        1.0  Life Sciences         2.0  Female       1.0
# ...

# %%
data.dtypes
# Out:
# Age                        float64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome           float64
# Education                  float64
# EducationField              object
# EmployeeID                 float64
# Gender                      object
# JobLevel                   float64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome              float64
# NumCompaniesWorked         float64
# PercentSalaryHike          float64
# StockOptionLevel           float64
# TotalWorkingYears          float64
# TrainingTimesLastYear      float64
# YearsAtCompany             float64
# YearsSinceLastPromotion    float64
# YearsWithCurrManager       float64
# EnvironmentSatisfaction    float64
# JobSatisfaction            float64
# WorkLifeBalance            float64
# JobInvolvement             float64
# PerformanceRating          float64
# Avg Time Spent(Mins)       float64
# ...

# %%
data
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     51.0        No      Travel_Rarely                   Sales
# 1     31.0       Yes  Travel_Frequently  Research & Development
# 2     32.0        No  Travel_Frequently  Research & Development
# 3     38.0        No         Non-Travel  Research & Development
# 4     32.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 4295  29.0        No      Travel_Rarely                   Sales
# 4296  42.0        No      Travel_Rarely  Research & Development
# 4297  29.0        No      Travel_Rarely  Research & Development
# 4298  25.0        No      Travel_Rarely  Research & Development
# 4299  42.0        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                  6.0        2.0  Life Sciences         1.0  Female
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.boxplot(data.MonthlyIncome)
plt.title('Box Plot of Data')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(datatime)
plt.title('Box Plot of Data')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.show()

# %%
datatime=data['Avg Time Spent(Mins)']

# %%
datatime
# Out:
# 0       442.0
# 1       463.0
# 2       420.0
# 3       431.0
# 4       480.0
#         ...
# 4295    504.0
# 4296    507.0
# 4297    498.0
# 4298    493.0
# 4299    497.0
# Name: Avg Time Spent(Mins), Length: 4300, dtype: float64

# %%
#Discretization (Age)
data['Age'] = np.where((data['Age'] > 25) & (data['Age'] <= 35), 'Fresh', 
                       np.where((data['Age'] > 35) & (data['Age'] <= 50), 'Mid-level',
                                np.where(data['Age'] > 50, 'Senior-level', 'Executive-level')))

# %%
data
# Out:
#                   Age Attrition     BusinessTravel              Department  \
# 0        Senior-level        No      Travel_Rarely                   Sales
# 1               Fresh       Yes  Travel_Frequently  Research & Development
# 2               Fresh        No  Travel_Frequently  Research & Development
# 3           Mid-level        No         Non-Travel  Research & Development
# 4               Fresh        No      Travel_Rarely  Research & Development
# ...               ...       ...                ...                     ...
# 4295            Fresh        No      Travel_Rarely                   Sales
# 4296        Mid-level        No      Travel_Rarely  Research & Development
# 4297            Fresh        No      Travel_Rarely  Research & Development
# 4298  Executive-level        No      Travel_Rarely  Research & Development
# 4299        Mid-level        No      Travel_Rarely                   Sales
#
# ...

# %%
#Discretization (Years at Company)
data['YearsAtCompany'] = np.where((data['YearsAtCompany'] > 1) & (data['YearsAtCompany'] <= 5), 'Apprentice', 
                       np.where((data['YearsAtCompany'] > 5) & (data['YearsAtCompany'] <= 10), 'Journeyman',
                                np.where(data['YearsAtCompany'] > 15, 'Expert', 'Master')))

# %%
data
# Out:
#                   Age Attrition     BusinessTravel              Department  \
# 0        Senior-level        No      Travel_Rarely                   Sales
# 1               Fresh       Yes  Travel_Frequently  Research & Development
# 2               Fresh        No  Travel_Frequently  Research & Development
# 3           Mid-level        No         Non-Travel  Research & Development
# 4               Fresh        No      Travel_Rarely  Research & Development
# ...               ...       ...                ...                     ...
# 4295            Fresh        No      Travel_Rarely                   Sales
# 4296        Mid-level        No      Travel_Rarely  Research & Development
# 4297            Fresh        No      Travel_Rarely  Research & Development
# 4298  Executive-level        No      Travel_Rarely  Research & Development
# 4299        Mid-level        No      Travel_Rarely                   Sales
#
# ...

# %%
#Feature encoding (Attrition)
data['Attrition']=data['Attrition'].replace(['Yes','No'],[1,0])

# %%
data
# Out:
#                   Age  Attrition     BusinessTravel              Department  \
# 0        Senior-level          0      Travel_Rarely                   Sales
# 1               Fresh          1  Travel_Frequently  Research & Development
# 2               Fresh          0  Travel_Frequently  Research & Development
# 3           Mid-level          0         Non-Travel  Research & Development
# 4               Fresh          0      Travel_Rarely  Research & Development
# ...               ...        ...                ...                     ...
# 4295            Fresh          0      Travel_Rarely                   Sales
# 4296        Mid-level          0      Travel_Rarely  Research & Development
# 4297            Fresh          0      Travel_Rarely  Research & Development
# 4298  Executive-level          0      Travel_Rarely  Research & Development
# 4299        Mid-level          0      Travel_Rarely                   Sales
#
# ...

# %%
data['Gender']=data['Gender'].replace(['Male','Female'],[1,0])

# %%
data
# Out:
#                   Age  Attrition     BusinessTravel              Department  \
# 0        Senior-level          0      Travel_Rarely                   Sales
# 1               Fresh          1  Travel_Frequently  Research & Development
# 2               Fresh          0  Travel_Frequently  Research & Development
# 3           Mid-level          0         Non-Travel  Research & Development
# 4               Fresh          0      Travel_Rarely  Research & Development
# ...               ...        ...                ...                     ...
# 4295            Fresh          0      Travel_Rarely                   Sales
# 4296        Mid-level          0      Travel_Rarely  Research & Development
# 4297            Fresh          0      Travel_Rarely  Research & Development
# 4298  Executive-level          0      Travel_Rarely  Research & Development
# 4299        Mid-level          0      Travel_Rarely                   Sales
#
# ...

# %%
#Discretization using Data Distribution (Avg Time Spent(Mins)
Q1=data ["Avg Time Spent(Mins)"].quantile(0.25)
Q2=data['Avg Time Spent(Mins)'].quantile(0.50)
Q3=data[ 'Avg Time Spent(Mins)'].quantile(0.75)
IQR=Q3-Q1
uw=Q3+1.5*IQR
lw=Q1-1.5*IQR

# %%
column = 'Avg Time Spent(Mins)' 

data[column] = np.where(data[column] < lw, 'lower_outlier',
                         np.where((data[column] >= lw) & (data[column] <= Q1), 'low', 
                                  np.where((data[column] > Q1) & (data[column] <= Q2), 'low_median',
                                           np.where((data[column] > Q2) & (data[column] <= Q3), 'high_median',
                                                    np.where((data[column] > Q3) & (data[column] <= Q3 + 1.5 * IQR), 'high',
                                                             'upper_outlier')))))

# %%
data
# Out:
#                   Age  Attrition     BusinessTravel              Department  \
# 0        Senior-level          0      Travel_Rarely                   Sales
# 1               Fresh          1  Travel_Frequently  Research & Development
# 2               Fresh          0  Travel_Frequently  Research & Development
# 3           Mid-level          0         Non-Travel  Research & Development
# 4               Fresh          0      Travel_Rarely  Research & Development
# ...               ...        ...                ...                     ...
# 4295            Fresh          0      Travel_Rarely                   Sales
# 4296        Mid-level          0      Travel_Rarely  Research & Development
# 4297            Fresh          0      Travel_Rarely  Research & Development
# 4298  Executive-level          0      Travel_Rarely  Research & Development
# 4299        Mid-level          0      Travel_Rarely                   Sales
#
# ...

# %%
#Z Score Normalization (Distance From Home)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data['DistanceFromHome'] = scaler.fit_transform(data[['DistanceFromHome']]).round(2)

# %%
data
# Out:
#                   Age  Attrition     BusinessTravel              Department  \
# 0        Senior-level          0      Travel_Rarely                   Sales
# 1               Fresh          1  Travel_Frequently  Research & Development
# 2               Fresh          0  Travel_Frequently  Research & Development
# 3           Mid-level          0         Non-Travel  Research & Development
# 4               Fresh          0      Travel_Rarely  Research & Development
# ...               ...        ...                ...                     ...
# 4295            Fresh          0      Travel_Rarely                   Sales
# 4296        Mid-level          0      Travel_Rarely  Research & Development
# 4297            Fresh          0      Travel_Rarely  Research & Development
# 4298  Executive-level          0      Travel_Rarely  Research & Development
# 4299        Mid-level          0      Travel_Rarely                   Sales
#
# ...

# %%
#MinMax Normalization (Years since last promotion)
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data['YearsSinceLastPromotion']=scaler.fit_transform(data[['YearsSinceLastPromotion']]).round(2)

# %%
#MinMax Normalization (Years with current manager)
data['YearsWithCurrManager']=scaler.fit_transform(data[['YearsWithCurrManager']]).round(2)

# %%
data
# Out:
#                   Age  Attrition     BusinessTravel              Department  \
# 0        Senior-level          0      Travel_Rarely                   Sales
# 1               Fresh          1  Travel_Frequently  Research & Development
# 2               Fresh          0  Travel_Frequently  Research & Development
# 3           Mid-level          0         Non-Travel  Research & Development
# 4               Fresh          0      Travel_Rarely  Research & Development
# ...               ...        ...                ...                     ...
# 4295            Fresh          0      Travel_Rarely                   Sales
# 4296        Mid-level          0      Travel_Rarely  Research & Development
# 4297            Fresh          0      Travel_Rarely  Research & Development
# 4298  Executive-level          0      Travel_Rarely  Research & Development
# 4299        Mid-level          0      Travel_Rarely                   Sales
#
# ...

# %%
#Z Score Normalization (Absences)

scaler = StandardScaler()
data['Absences'] = scaler.fit_transform(data[['Absences']]).round(2)

# %%
data
# Out:
#                   Age  Attrition     BusinessTravel              Department  \
# 0        Senior-level          0      Travel_Rarely                   Sales
# 1               Fresh          1  Travel_Frequently  Research & Development
# 2               Fresh          0  Travel_Frequently  Research & Development
# 3           Mid-level          0         Non-Travel  Research & Development
# 4               Fresh          0      Travel_Rarely  Research & Development
# ...               ...        ...                ...                     ...
# 4295            Fresh          0      Travel_Rarely                   Sales
# 4296        Mid-level          0      Travel_Rarely  Research & Development
# 4297            Fresh          0      Travel_Rarely  Research & Development
# 4298  Executive-level          0      Travel_Rarely  Research & Development
# 4299        Mid-level          0      Travel_Rarely                   Sales
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
encoded_df = pd.get_dummies(data, columns=['Age', 'YearsAtCompany'])

# %%
categorical_cols = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']
label_encoder = LabelEncoder()

# %%
encoded_time_spent = label_encoder.fit_transform(encoded_df['Avg Time Spent(Mins)'])

# Replace the original column with the encoded values
encoded_df['Avg Time Spent(Mins)'] = encoded_time_spent

# %%
# Perform one-hot encoding for the categorical variable
encoded_df = pd.get_dummies(encoded_df, columns=['Avg Time Spent(Mins)'])

# %%
encoded_df
# Out:
#       Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0             0               2           2             -0.39        2.0
# 1             1               1           1              0.10        1.0
# 2             0               1           1              0.96        4.0
# 3             0               0           1             -0.89        5.0
# 4             0               2           1              0.10        1.0
# ...         ...             ...         ...               ...        ...
# 4295          0               2           2             -0.64        3.0
# 4296          0               2           1             -0.52        4.0
# 4297          0               2           1             -0.89        4.0
# 4298          0               2           1              1.95        2.0
# 4299          0               2           2              1.09        2.0
#
#       EducationField  EmployeeID  Gender  JobLevel  JobRole  ...  \
# ...

# %%
for col in categorical_cols:
    data[col] = label_encoder.fit_transform(data[col])

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns=['Attrition'])  # Features
y = data['Attrition']  # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#                   Age  BusinessTravel  Department  DistanceFromHome  \
# 847             Fresh               2           2             -0.39
# 3734            Fresh               2           1             -0.89
# 1833        Mid-level               2           1              1.95
# 2787     Senior-level               2           2             -1.01
# 3245        Mid-level               0           1             -1.01
# ...               ...             ...         ...               ...
# 3444  Executive-level               2           1             -0.39
# 466         Mid-level               2           2              2.20
# 3092        Mid-level               2           1             -0.89
# 3772            Fresh               2           1             -1.01
# 860         Mid-level               2           1             -1.01
#
#       Education  EducationField  EmployeeID  Gender  JobLevel  JobRole  ...  \
# ...

# %%
y_train
# Out:
# 847     0
# 3734    0
# 1833    0
# 2787    0
# 3245    0
#        ..
# 3444    0
# 466     0
# 3092    0
# 3772    0
# 860     0
# Name: Attrition, Length: 3010, dtype: int64

# %%
X_test
# Out:
#                Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 1760     Mid-level               2           1              0.10        4.0
# 3035         Fresh               1           2              0.96        1.0
# 1921     Mid-level               2           0             -0.89        3.0
# 1188         Fresh               2           1             -1.01        4.0
# 109          Fresh               2           1              2.45        3.0
# ...            ...             ...         ...               ...        ...
# 4199  Senior-level               2           2              0.59        2.0
# 3518  Senior-level               1           2              1.46        4.0
# 258      Mid-level               2           1              0.35        5.0
# 3271         Fresh               0           1             -1.01        2.0
# 386          Fresh               2           2              1.83        5.0
#
# ...

# %%
y_test
# Out:
# 1760    0
# 3035    1
# 1921    0
# 1188    1
# 109     0
#        ..
# 4199    0
# 3518    0
# 258     0
# 3271    0
# 386     0
# Name: Attrition, Length: 1290, dtype: int64

# %%
print("Training set shape (X_train):", X_train.shape)
print("Testing set shape (X_test):", X_test.shape)
print("Training set shape (y_train):", y_train.shape)
print("Testing set shape (y_test):", y_test.shape)
# Out:
# Training set shape (X_train): (3010, 27)
# Testing set shape (X_test): (1290, 27)
# Training set shape (y_train): (3010,)
# Testing set shape (y_test): (1290,)

# %%
encoded_df.to_excel('processed_data.xlsx',index=False)
